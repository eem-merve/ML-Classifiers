# %%
import pandas as pd
df=pd.read_csv("/content/unbalanceddata.csv")

# %%
df
# Out:
#          PMTno     Time  isCherenkov   Energy
# 0           14  4.32777            0  3.15073
# 1           14  3.52581            0  3.32453
# 2           19  2.30603            1  3.33555
# 3           21  2.88468            0  3.25262
# 4           12  4.24241            0  3.40237
# ...        ...      ...          ...      ...
# 1167375     21  1.94632            1  2.89260
# 1167376      4  5.72637            0  3.31828
# 1167377     14  4.16993            0  3.49550
# 1167378      9  3.94950            0  2.55363
# 1167379      8  3.09627            0  3.24163
#
# [1167380 rows x 4 columns]

# %%
pip install pycaret
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import PyCaret tool
from pycaret.classification import *

# Preperation of PyCaret tool
clf_setup = setup(data=df, target='isCherenkov', session_id=123)

# Comparison of models
leaderboard = compare_models()

# 5. Lider tablosunu görüntüleyin
print(leaderboard)
# Out:
# <style type="text/css">
# #T_c7ae0_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c7ae0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7ae0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c7ae0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7ae0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7ae0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c7ae0_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c7ae0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7ae0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c7ae0_row1_col1" class="data row1 col1" >isCherenkov</td>
#     </tr>
#     <tr>
#       <th id="T_c7ae0_level0_row2" class="row_heading level0 row2" >2</th>
# ...
